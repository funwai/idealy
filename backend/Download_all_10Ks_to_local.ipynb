# %%
import os
from google.cloud import storage
from google.oauth2 import service_account
from dotenv import load_dotenv
load_dotenv()

def download_all_10k_texts(local_output_folder, service_account_path=None):
    """
    Downloads all .txt 10-K files stored in:
    company_details/EDGAR (US)/filings/
    and saves them into a local folder.
    """

    # Load service account path from .env if not provided
    if service_account_path is None:
        service_account_path = os.getenv("FIREBASE_SERVICE_ACCOUNT_JSON")

    if not service_account_path or not os.path.exists(service_account_path):
        raise FileNotFoundError(
            f"❌ Service account file not found at: {service_account_path}"
        )

    # Create Firebase Storage client
    credentials = service_account.Credentials.from_service_account_file(service_account_path)
    client = storage.Client(credentials=credentials, project=credentials.project_id)

    bucket_name = "funwai-resume.firebasestorage.app"
    bucket = client.bucket(bucket_name)

    # Folder where your cleaned .txt files live inside Firebase Storage
    prefix = "company_details/EDGAR (US)"

    # Ensure local output folder exists
    os.makedirs(local_output_folder, exist_ok=True)

    print("🔍 Checking for .txt files in bucket...")

    # List all files under prefix
    blobs = bucket.list_blobs(prefix=prefix)

    download_count = 0

    for blob in blobs:
        if blob.name.endswith(".txt"):  # Only download .txt files
            filename = blob.name.split("/")[-1]
            local_path = os.path.join(local_output_folder, filename)

            print(f"⬇️ Downloading {filename} ...")

            blob.download_to_filename(local_path)
            download_count += 1

    if download_count == 0:
        print("⚠️ No .txt files found in the specified folder.")
    else:
        print(f"✅ Download complete. {download_count} files saved to {local_output_folder}")


# ---- Run the download ----

download_all_10k_texts(
    local_output_folder="./clean_10k_texts"   # choose your folder
)
# Out:
# 🔍 Checking for .txt files in bucket...
# ⬇️ Downloading AAPL_2025_10K.txt ...
# ⬇️ Downloading ABBV_2024_10K.txt ...
# ⬇️ Downloading ABNB_2024_10K.txt ...
# ⬇️ Downloading ABT_2024_10K.txt ...
# ⬇️ Downloading ACN_2025_10K.txt ...
# ⬇️ Downloading ADBE_2024_10K.txt ...
# ⬇️ Downloading ADI_2024_10K.txt ...
# ⬇️ Downloading AEP_2024_10K.txt ...
# ⬇️ Downloading AJG_2024_10K.txt ...
# ⬇️ Downloading AMAT_2024_10K.txt ...
# ⬇️ Downloading AMCR_2025_10K.txt ...
# ⬇️ Downloading AMD_2024_10K.txt ...
# ⬇️ Downloading AME_2024_10K.txt ...
# ⬇️ Downloading AMZN_2024_10K.txt ...
# ⬇️ Downloading AON_2024_10K.txt ...
# ⬇️ Downloading A_2024_10K.txt ...
# ⬇️ Downloading BAC_2024_10K.txt ...
# ⬇️ Downloading BALL_2024_10K.txt ...
# ⬇️ Downloading BA_2024_10K.txt ...
# ⬇️ Downloading BBY_2025_10K.txt ...
# ⬇️ Downloading BKNG_2024_10K.txt ...
# ⬇️ Downloading BKR_2024_10K.txt ...
# ⬇️ Downloading BMY_2024_10K.txt ...
# ⬇️ Downloading BRK-B_2024_10K.txt ...
# ⬇️ Downloading BR_2025_10K.txt ...
# ⬇️ Downloading CAH_2025_10K.txt ...
# ⬇️ Downloading CAT_2024_10K.txt ...
# ⬇️ Downloading CBOE_2024_10K.txt ...
# ⬇️ Downloading CCL_2024_10K.txt ...
# ⬇️ Downloading CHD_2024_10K.txt ...
# ⬇️ Downloading CI_2024_10K.txt ...
# ⬇️ Downloading CLX_2025_10K.txt ...
# ⬇️ Downloading CMCSA_2024_10K.txt ...
# ⬇️ Downloading CME_2024_10K.txt ...
# ⬇️ Downloading CNP_2024_10K.txt ...
# ⬇️ Downloading COIN_2024_10K.txt ...
# ⬇️ Downloading COP_2024_10K.txt ...
# ⬇️ Downloading COST_2025_10K.txt ...
# ⬇️ Downloading CPAY_2024_10K.txt ...
# ⬇️ Downloading CRL_2024_10K.txt ...
# ⬇️ Downloading CRM_2025_10K.txt ...
# ⬇️ Downloading CRWD_2025_10K.txt ...
# ⬇️ Downloading CSCO_2025_10K.txt ...
# ⬇️ Downloading CTRA_2024_10K.txt ...
# ⬇️ Downloading CTSH_2024_10K.txt ...
# ⬇️ Downloading CVS_2024_10K.txt ...
# ⬇️ Downloading CVX_2024_10K.txt ...
# ⬇️ Downloading C_2024_10K.txt ...
# ⬇️ Downloading DAL_2024_10K.txt ...
# ⬇️ Downloading DASH_2024_10K.txt ...
# ⬇️ Downloading DDOG_2024_10K.txt ...
# ⬇️ Downloading DD_2024_10K.txt ...
# ⬇️ Downloading DELL_2025_10K.txt ...
# ⬇️ Downloading DE_2024_10K.txt ...
# ⬇️ Downloading DIS_2025_10K.txt ...
# ⬇️ Downloading DLTR_2025_10K.txt ...
# ⬇️ Downloading D_2024_10K.txt ...
# ⬇️ Downloading EA_2025_10K.txt ...
# ⬇️ Downloading EBAY_2024_10K.txt ...
# ⬇️ Downloading EFX_2024_10K.txt ...
# ⬇️ Downloading EL_2025_10K.txt ...
# ⬇️ Downloading EOG_2024_10K.txt ...
# ⬇️ Downloading ETN_2024_10K.txt ...
# ⬇️ Downloading EXPE_2024_10K.txt ...
# ⬇️ Downloading FDS_2025_10K.txt ...
# ⬇️ Downloading FDX_2025_10K.txt ...
# ⬇️ Downloading FE_2024_10K.txt ...
# ⬇️ Downloading FICO_2025_10K.txt ...
# ⬇️ Downloading F_2024_10K.txt ...
# ⬇️ Downloading GDDY_2024_10K.txt ...
# ⬇️ Downloading GE_2024_10K.txt ...
# ⬇️ Downloading GIS_2025_10K.txt ...
# ⬇️ Downloading GM_2024_10K.txt ...
# ⬇️ Downloading GOOGL_2024_10K.txt ...
# ⬇️ Downloading GOOG_2024_10K.txt ...
# ⬇️ Downloading GS_2024_10K.txt ...
# ⬇️ Downloading HAL_2024_10K.txt ...
# ⬇️ Downloading HAS_2024_10K.txt ...
# ⬇️ Downloading HCA_2024_10K.txt ...
# ⬇️ Downloading HD_2025_10K.txt ...
# ⬇️ Downloading HLT_2024_10K.txt ...
# ⬇️ Downloading HON_2024_10K.txt ...
# ⬇️ Downloading HPE_2024_10K.txt ...
# ⬇️ Downloading HSIC_2024_10K.txt ...
# ⬇️ Downloading HUM_2024_10K.txt ...
# ⬇️ Downloading IBM_2024_10K.txt ...
# ⬇️ Downloading ICE_2024_10K.txt ...
# ⬇️ Downloading INTC_2024_10K.txt ...
# ⬇️ Downloading INTU_2025_10K.txt ...
# ⬇️ Downloading IT_2024_10K.txt ...
# ⬇️ Downloading JNJ_2024_10K.txt ...
# ⬇️ Downloading JPM_2024_10K.txt ...
# ⬇️ Downloading J_2024_10K.txt ...
# ⬇️ Downloading KDP_2024_10K.txt ...
# ⬇️ Downloading KHC_2024_10K.txt ...
# ⬇️ Downloading KIM_2024_10K.txt ...
# ⬇️ Downloading KKR_2024_10K.txt ...
# ⬇️ Downloading KMB_2024_10K.txt ...
# ⬇️ Downloading KMX_2025_10K.txt ...
# ⬇️ Downloading KO_2024_10K.txt ...
# ⬇️ Downloading KR_2025_10K.txt ...
# ⬇️ Downloading K_2024_10K.txt ...
# ⬇️ Downloading LH_2024_10K.txt ...
# ⬇️ Downloading LIN_2024_10K.txt ...
# ⬇️ Downloading LLY_2024_10K.txt ...
# ⬇️ Downloading LMT_2024_10K.txt ...
# ⬇️ Downloading LOW_2025_10K.txt ...
# ⬇️ Downloading LULU_2025_10K.txt ...
# ⬇️ Downloading L_2024_10K.txt ...
# ⬇️ Downloading MAR_2024_10K.txt ...
# ⬇️ Downloading MA_2024_10K.txt ...
# ⬇️ Downloading MCD_2024_10K.txt ...
# ⬇️ Downloading MCO_2024_10K.txt ...
# ⬇️ Downloading MDLZ_2024_10K.txt ...
# ⬇️ Downloading META_2024_10K.txt ...
# ⬇️ Downloading MET_2024_10K.txt ...
# ⬇️ Downloading MMM_2024_10K.txt ...
# ⬇️ Downloading MNST_2024_10K.txt ...
# ⬇️ Downloading MOS_2024_10K.txt ...
# ⬇️ Downloading MO_2024_10K.txt ...
# ⬇️ Downloading MPWR_2024_10K.txt ...
# ⬇️ Downloading MRNA_2024_10K.txt ...
# ⬇️ Downloading MSCI_2024_10K.txt ...
# ⬇️ Downloading MSFT_2025_10K.txt ...
# ⬇️ Downloading MSI_2024_10K.txt ...
# ⬇️ Downloading MS_2024_10K.txt ...
# ⬇️ Downloading MU_2025_10K.txt ...
# ⬇️ Downloading NDAQ_2024_10K.txt ...
# ⬇️ Downloading NFLX_2024_10K.txt ...
# ⬇️ Downloading NI_2024_10K.txt ...
# ⬇️ Downloading NKE_2025_10K.txt ...
# ⬇️ Downloading XYZ_2024_10K.txt ...
# ⬇️ Downloading YUM_2024_10K.txt ...
# ✅ Download complete. 133 files saved to ./clean_10k_texts
